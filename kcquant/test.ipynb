# %%
from kcquant import get_colors

# %%
from PIL import Image
import numpy as np 

img = Image.open('/Users/kacikus/Dropbox/AutomatedMineralogy_Project/Automated-Mineralogy/Images/EDF17-1.png').convert('RGB')
get_colors(np.array(img), color='RGB', top=10)
